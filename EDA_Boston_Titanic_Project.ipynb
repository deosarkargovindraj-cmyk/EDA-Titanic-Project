# %% [markdown]
# # Exploratory Data Analysis (EDA) Project
# ## Boston Housing & Titanic Dataset
# Tech Stack: Python (Pandas, NumPy, Scikit-Learn), Jupyter Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ## 1. Load Boston Housing Dataset

# %%
boston = fetch_openml(name='boston', version=1, as_frame=True)
boston_df = boston.frame
boston_df.head()

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(boston_df.corr(), cmap='coolwarm')
plt.title('Correlation Heatmap - Boston Housing')
plt.show()

# %% [markdown]
# ## 2. Load and Clean Titanic Dataset

# %%
titanic = sns.load_dataset('titanic')
titanic['age'].fillna(titanic['age'].median(), inplace=True)
titanic['embarked'].fillna(titanic['embarked'].mode()[0], inplace=True)
titanic.drop(['deck'], axis=1, inplace=True)
titanic.head()

# %% [markdown]
# ## 3. Univariate Analysis

# %%
sns.countplot(x='survived', data=titanic)
plt.title('Survival Count')
plt.show()

sns.histplot(titanic['age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ## 4. Bivariate Analysis

# %%
sns.countplot(x='sex', hue='survived', data=titanic)
plt.title('Survival by Gender')
plt.show()

sns.countplot(x='pclass', hue='survived', data=titanic)
plt.title('Survival by Class')
plt.show()

sns.boxplot(x='survived', y='age', data=titanic)
plt.title('Survival by Age')
plt.show()

# %% [markdown]
# ## 5. Logistic Regression Model

# %%
data = titanic[['survived','pclass','sex','age','fare','embarked']]
data = pd.get_dummies(data, drop_first=True)

X = data.drop('survived', axis=1)
y = data['survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print('Accuracy:', accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %% [markdown]
# ## Conclusion
# - Females and 1st class passengers had higher survival rate.
# - Logistic Regression achieved good classification accuracy (~75-80%).
